# %% [markdown]
# # EDA

# %%
import pandas as pd

df = pd.read_csv("data_1.csv")
df.head()
df.info()
df['Label'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STT        683 non-null    int64
#  1   Thông tin  683 non-null    object
#  2   Label      683 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 16.1+ KB
# Label
# Tin tức       272
# Giới thiệu    153
# Hợp tác       138
# Nghiên cứu    120
# Name: count, dtype: int64

# %%
df['len_char'] = df['Thông tin'].str.len()
df['len_word'] = df['Thông tin'].str.split().apply(len)

df[['len_char','len_word']].describe()
# Out:
#          len_char    len_word
# count  683.000000  683.000000
# mean   110.358712   24.087848
# std     77.577878   16.561745
# min     19.000000    4.000000
# 25%     67.000000   15.000000
# 50%     86.000000   19.000000
# 75%    117.000000   26.000000
# max    606.000000  127.000000

# %%
import matplotlib.pyplot as plt

plt.hist(df['len_word'], bins=20)
plt.xlabel("Số từ")
plt.ylabel("Số mẫu")
plt.show()

# %% [markdown]
# # Augmentation

# %% [markdown]
# # EDA after augmentation

# %%
import pandas as pd

df = pd.read_csv("data.csv")
df.head()
df.info()
df['Label'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 866 entries, 0 to 865
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STT        866 non-null    int64
#  1   Thông tin  866 non-null    object
#  2   Label      866 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 20.4+ KB
# Label
# Tin tức       536
# Hợp tác       215
# Nghiên cứu    115
# Name: count, dtype: int64

# %%
df['len_char'] = df['Thông tin'].str.len()
df['len_word'] = df['Thông tin'].str.split().apply(len)

df[['len_char','len_word']].describe()
# Out:
#          len_char    len_word
# count  866.000000  866.000000
# mean    80.139723   16.523095
# std     25.113939    5.404990
# min     20.000000    4.000000
# 25%     62.000000   12.000000
# 50%     78.000000   16.000000
# 75%     97.000000   20.000000
# max    168.000000   36.000000

# %%
import matplotlib.pyplot as plt

plt.hist(df['len_word'], bins=20)
plt.xlabel("Số từ")
plt.ylabel("Số mẫu")
plt.show()
