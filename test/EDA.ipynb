# %% [markdown]
# # EDA

# %%
import pandas as pd

df = pd.read_csv("data_1.csv")
df.head()
df.info()
df['Label'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STT        683 non-null    int64
#  1   Thông tin  683 non-null    object
#  2   Label      683 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 16.1+ KB
# Label
# Tin tức       272
# Giới thiệu    153
# Hợp tác       138
# Nghiên cứu    120
# Name: count, dtype: int64

# %%
df['len_char'] = df['Thông tin'].str.len()
df['len_word'] = df['Thông tin'].str.split().apply(len)

df[['len_char','len_word']].describe()
# Out:
#          len_char    len_word
# count  683.000000  683.000000
# mean   110.358712   24.087848
# std     77.577878   16.561745
# min     19.000000    4.000000
# 25%     67.000000   15.000000
# 50%     86.000000   19.000000
# 75%    117.000000   26.000000
# max    606.000000  127.000000

# %%
import matplotlib.pyplot as plt

plt.hist(df['len_word'], bins=20)
plt.xlabel("Số từ")
plt.ylabel("Số mẫu")
plt.show()

# %% [markdown]
# # Augmentation

# %% [markdown]
# # EDA after augmentation

# %%
import pandas as pd

df = pd.read_csv("output_augmented_vi_en.csv")
df.head()
df.info()
df['Label'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1210 entries, 0 to 1209
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STT              1210 non-null   int64
#  1   Thông tin        1210 non-null   object
#  2   Label            1210 non-null   object
#  3   thong_tin_norm   1210 non-null   object
#  4   tokens           1210 non-null   object
#  5   thong_tin_final  1210 non-null   object
#  6   language         1210 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 66.3+ KB
# Label
# Tin tức       459
# Giới thiệu    278
# Hợp tác       249
# Nghiên cứu    224
# Name: count, dtype: int64

# %%
df['len_char'] = df['Thông tin'].str.len()
df['len_word'] = df['Thông tin'].str.split().apply(len)

df[['len_char','len_word']].describe()
# Out:
#           len_char     len_word
# count  1210.000000  1210.000000
# mean    117.014050    21.669421
# std      79.943046    14.923565
# min      16.000000     2.000000
# 25%      69.000000    13.000000
# 50%      92.000000    17.000000
# 75%     128.000000    24.000000
# max     606.000000   127.000000

# %%
import matplotlib.pyplot as plt

plt.hist(df['len_word'], bins=20)
plt.xlabel("Số từ")
plt.ylabel("Số mẫu")
plt.show()
